# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/master/studytime2.csv")
df["day of week"] = pd.Categorical(df["day of week"], categories=["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"], ordered=True)

# %%
df
# Out:
#      term  week day of week        course  duration           start_date  \
# 0    fa23     5      Monday      MATH 241        60  2023-09-18 19:30:00
# 1    fa23     5     Tuesday  PHYS 213/214        15  2023-09-19 19:30:00
# 2    fa23     5   Wednesday      STAT 107        15  2023-09-20 10:00:00
# 3    fa23     5    Thursday      MATH 241        60  2023-09-21 13:50:00
# 4    fa23     5    Thursday  PHYS 213/214        30  2023-09-21 15:00:00
# ..    ...   ...         ...           ...       ...                  ...
# 877  sp25     3      Sunday      Research       120  2025-02-09 09:00:00
# 878  sp25     3      Sunday      ASTR 405       120  2025-02-09 14:30:00
# 879  sp25     3      Sunday  CHEM 104/105        15  2025-02-09 16:30:00
# 880  sp25     3      Sunday  CHEM 104/105        15  2025-02-09 16:45:00
# 881  sp25     3      Sunday      GEOL 432        30  2025-02-09 17:00:00
#
#                 end_date    due_date                       title
# ...

# %%
df2 = df[df['term'] == 'sp24'].groupby(['day of week', 'course', 'term']).agg('mean').reset_index()[['day of week', 'course', 'duration']]
sns.barplot(df2, x='day of week', y='duration')
# Out:
# /var/folders/41/_gkgvhb94wd4156zplzr4cg00000gn/T/ipykernel_3103/190276188.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2 = df[df['term'] == 'sp24'].drop('title',axis=1).groupby(['day of week', 'course', 'term']).agg('mean').reset_index()[['day of week', 'course', 'duration']]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Developer/Misc/studytime/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# ...

# %%
df[df['term'] == 'fa24'][['week', 'day of week', 'duration']].groupby(["day of week", "week"]).agg('sum').reset_index()[['day of week', 'duration']].groupby('day of week').agg('mean')
# Out:
# /var/folders/41/_gkgvhb94wd4156zplzr4cg00000gn/T/ipykernel_7156/739961838.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[df['term'] == 'fa24'][['week', 'day of week', 'time spent (min)']].groupby(["day of week", "week"]).agg('sum').reset_index()[['day of week', 'time spent (min)']].groupby('day of week').agg('mean')
# /var/folders/41/_gkgvhb94wd4156zplzr4cg00000gn/T/ipykernel_7156/739961838.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ...

# %%
df[df['term'] == 'sp25'][['week', 'duration']].groupby(['week']).agg('sum') / 60
# Out:
#        duration
# week
# 1     16.766667
# 2     27.000000
# 3     28.750000

# %%
df[df['term'] == 'sp25'][['week', 'course', 'duration']].groupby(['week', 'course']).agg('sum') / 60
# Out:
#                     duration
# week course
# 1    ASTR 405       1.000000
#      CHEM 104/105   2.516667
#      CS 307         0.750000
#      Research      12.500000
# 2    ASTR 405       6.250000
#      CHEM 104/105   3.250000
#      CS 307         0.250000
#      GEOL 432       8.250000
#      Research       9.000000
# 3    ASTR 405       5.500000
#      CHEM 104/105   1.750000
#      CS 307         2.500000
#      GEOL 432      11.250000
#      Research       7.750000
